# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import numpy as np
from pyuvdata import UVCal, UVData, UVFlag
import os
import sys
import glob
import uvtools as uvt
from astropy.time import Time
from astropy.coordinates import EarthLocation, SkyCoord, AltAz, Angle
import pandas
import warnings 
import copy
from hera_notebook_templates import utils
import hera_qm
from hera_mc import cm_hookup
import h5py
import importlib
from scipy import stats
import scipy
from IPython.display import display, HTML
#warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#get data location
JD = os.environ['JULIANDATE']
data_path = os.environ['DATA_PATH']
utc = Time(JD, format='jd').datetime
print(f'JD = {JD}')
print(f'Date = {utc.month}-{utc.day}-{utc.year}')
print(f'data_path = "{data_path}"')
# Out:
# JD = 2459269
# Date = 2-23-2021
# data_path = "/mnt/sn1"

# %%
# Load in data
HHfiles, difffiles, HHautos, diffautos, uvdx, uvdy = utils.load_data(data_path,JD)
    
uvd = UVData()
uvd_diff = UVData()
unread = True
i=0
while unread and i<len(HHautos):
    try:
        uvd.read(HHautos[i])
        unread = False
    except:
        i += 1
        continue
use_ants = [int(ant) for ant in uvd.get_ants()]
bls = [(ant, ant) for ant in use_ants]
uvd.read(HHfiles[::10], skip_bad_files=True, bls=bls)
uvd_diff.read(difffiles[::10], skip_bad_files=True, bls=bls)
lsts = uvd.lst_array

flagfile = glob.glob(os.path.join(HHfiles[0].split('zen')[0],'*total_stage_1_threshold_flags.h5'))    
uvf = UVFlag()
uvf.read(flagfile)
bls = [(ant, ant) for ant in uvd.get_ants()]
times_uvf = np.unique(uvf.time_array)
times_uvd = np.unique(uvd.time_array)
idx_times = [np.where(time_uvd == times_uvf)[0][0] for time_uvd in times_uvd]
uvd.flag_array[:,0,:,:] = np.repeat(uvf.flag_array[idx_times], len(bls), axis=0)
# Out:
# 240 sum files found between JDs 2459269.24566 and 2459269.46949
# 240 diff files found between JDs 2459269.24566 and 2459269.46949
# 240 sum auto files found between JDs 2459269.24566 and 2459269.46949
# 240 diff auto files found between JDs 2459269.24566 and 2459269.46949

# %% [markdown]
# ## LST Coverage

# %% [markdown]
# Shows the LSTs (in hours) and JDs for which data is collected. Green represents data, red means no data.

# %%
utils.plot_lst_coverage(uvd)

# %% [markdown]
# ## Delay spectrum

# %% [markdown]
# Delay spectrum CLEANed using uvtools.dspec.high_pass_fourier_filter with 7th-order Blackman-Harris window function. Odd/even visibilities are used to remove noise bias.

# %%
_data_cleaned_sq, data_rs_sq = utils.clean_ds(HHfiles[::10], bls, uvd, uvd_diff)

# %% [markdown]
# ## Waterfalls of delay spectra for autocorrelation

# %% [markdown]
# These plots show autocorrelation delay spectrum waterfalls of each antenna that is active and whose status qualifies for this notebook. For each node, antennas are ordered by SNAP number, and within that by SNAP input number. The antenna number label color corresponds to the a priori status of that antenna.

# %% [markdown]
# ### nn polarization

# %%
utils.plot_wfds(uvd, _data_cleaned_sq, 0)

# %% [markdown]
# ### ee polarization

# %%
utils.plot_wfds(uvd, _data_cleaned_sq, 1)

# %% [markdown]
# ### ne polarization

# %%
utils.plot_wfds(uvd, _data_cleaned_sq, 2)

# %% [markdown]
# ### en polarization

# %%
utils.plot_wfds(uvd, _data_cleaned_sq, 3)

# %% [markdown]
# ## Analysis of 2700ns features from delay spectra

# %% [markdown]
# This plot shows the relative amplitude at 2700 ns feature. The relative amplitude is calculated in dB with the mean amplitude at 2500-3000 ns compared to the mean amplitude at 2000-2500 ns. Larger values of relative feature amplitude indicate higher probability of detecting the peak at 2700 ns. Antennas in the same node are grouped by the shaded region.

# %%
utils.plot_antFeatureMap(uvd, _data_cleaned_sq, JD, pol='nn')

# %%
utils.plot_antFeatureMap(uvd, _data_cleaned_sq, JD, pol='ee')

# %% [markdown]
# This plot shows a matrix representing the 2700ns feature correlation of each baseline. The color bar indicates the amplitude of 2700ns (mean amplitude of 2500-3000ns delay spectrum) in dB which is the same as that in the above plot.

# %%
utils.CorrMatrix_2700ns(uvd, HHfiles, difffiles, flagfile, JD)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-cfdb98547ada> in <module>
# ----> 1 utils.CorrMatrix_2700ns(uvd, HHfiles, difffiles, flagfile, JD)
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/hera_notebook_templates/utils.py in CorrMatrix_2700ns(uvd, HHfiles, difffiles, flagfile, JD)
#    2373         uvd_data_ds.flag_array[:,0,:,:] = np.repeat(uvf.flag_array[idx_times], len(bls), axis=0)
#    2374
# -> 2375         _d_cleaned_sq, _ = clean_ds([HHfile], bls, uvd_data_ds, uvd_diff_ds, pols=pols, area=area)
#    2376
#    2377         freqs = uvd_data_ds.freq_array[0]
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/hera_notebook_templates/utils.py in clean_ds(HHfiles, bls, uvd_ds, uvd_diff, area, tol, skip_wgts, N_threads, freq_range, pols)
#    1894         for j, pol in enumerate(pols):
#    1895             key = (bl[0], bl[1], pol)
# -> 1896             _data_cleaned_sq[key], data_rs_sq[key] = _clean_ds_per_bl_pol(bl, pol, uvd_ds, uvd_diff, area, tol, skip_wgts, freq_range)
#    1897
#    1898     return _data_cleaned_sq, data_rs_sq
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/hera_notebook_templates/utils.py in _clean_ds_per_bl_pol(bl, pol, uvd, uvd_diff, area, tol, skip_wgts, freq_range)
#    1867         d_odd = (data-diff)*0.5
#    1868         d_even_cl, d_even_rs, _ = dspec.high_pass_fourier_filter(d_even, wgts, area*1e-9, freqs[1]-freqs[0],
# -> 1869                                                                  tol=tol, skip_wgt=skip_wgts, window='bh7')
#    1870         d_odd_cl, d_odd_rs, _ = dspec.high_pass_fourier_filter(d_odd, wgts, area*1e-9, freqs[1]-freqs[0],
#    1871                                                                tol=tol, skip_wgt=skip_wgts, window='bh7')
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/uvtools/dspec.py in high_pass_fourier_filter(data, wgts, filter_size, real_delta, clean2d, tol, window, skip_wgt, maxiter, gain, filt2d_mode, alpha, edgecut_low, edgecut_hi, add_clean_residual)
#     614     return vis_clean(data=data, wgts=wgts, filter_size=filter_size, real_delta=real_delta, clean2d=clean2d,
#     615                      tol=tol, window=window, skip_wgt=skip_wgt, maxiter=maxiter, gain=gain, filt2d_mode=filt2d_mode,
# --> 616                      alpha=alpha, edgecut_low=edgecut_low, edgecut_hi=edgecut_hi, add_clean_residual=add_clean_residual)
#     617
#     618 def dayenu_filter(x, data, wgts, filter_dimensions, filter_centers, filter_half_widths, filter_factors,
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/uvtools/dspec.py in vis_clean(data, wgts, filter_size, real_delta, clean2d, tol, window, skip_wgt, maxiter, gain, filt2d_mode, alpha, edgecut_low, edgecut_hi, add_clean_residual)
#     602                               mode='clean', filter_dims=filter_dims, tol=tol, window=window,
#     603                               maxiter=maxiter, gain=gain, filt2d_mode=filt2d_mode, alpha=alpha,
# --> 604                               edgecut_hi=edgecut_hi, edgecut_low=edgecut_low, add_clean_residual=add_clean_residual)
#     605
#     606
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/uvtools/dspec.py in fourier_filter(x, data, wgts, filter_centers, filter_half_widths, mode, filter_dims, skip_wgt, zero_residual_flags, **filter_kwargs)
#     494                        model, residual, info = _clean_filter(x=x, data=data, wgts=wgts, filter_centers=filter_centers, skip_wgt=skip_wgt,
#     495                                                             filter_half_widths=filter_half_widths, clean2d=filter2d, zero_residual_flags=zero_residual_flags,
# --> 496                                                              **filter_kwargs)
#     497                        if filter2d:
#     498                            info['filter_params']['axis_0'] = filter_kwargs
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/uvtools/dspec.py in _clean_filter(x, data, wgts, filter_centers, filter_half_widths, clean2d, tol, window, skip_wgt, maxiter, gain, filt2d_mode, alpha, edgecut_low, edgecut_hi, add_clean_residual, zero_residual_flags)
#    1670         for m in range(2):
#    1671             for fc, fw in zip(filter_centers[m], filter_half_widths[m]):
# -> 1672                 area_vecs[m] = _get_filter_area(x[m], fc, fw)
#    1673         area = np.outer(area_vecs[0], area_vecs[1])
#    1674     elif filt2d_mode == 'plus' and clean2d:
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/uvtools/dspec.py in _get_filter_area(x, filter_center, filter_width)
#     100     nx = len(x)
#     101     dx = np.mean(np.diff(x))
# --> 102     if not np.isinf(filter_width):
#     103         av = np.ones(len(x))
#     104         filter_size = ((-filter_center + filter_width), (filter_center + filter_width))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## HTML file for delay spectrum and autocorrelation plot is provided separately in the same directory

# %% [markdown]
# An HTML file which includes time-averaged delay spectra and autocorrelations for each antenna/pol is made in the directory of this notebook. Here is an explanation for the plots:
#
# Left panel: time averaged delay spectum of autocorrelation (blue) and noise from diff file representing the expected variance of the delay spectrum (red) $\sqrt{\sigma_{\rm diff}^2/N_{\rm t}}$ where $N_{\rm t}$ is the number of time sample. Ideally, we expect the delay spectrum is consistent with the noise level at $\tau > \sim250$ns
#
# Right panel: time averaged autocorrelations w/o (orange) and w/ xRFI flags (blue). Flagged one, which is used for making the delay spectrum, is shifted from the unflagged one for clarity

# %%
# html_filename = "delay_spectrum_JD{}.html".format(JD)
# utils.make_html_dspec(HHfiles[::10], html_filename, bls, uvd, uvd_diff, _data_cleaned_sq, data_rs_sq, JD)
