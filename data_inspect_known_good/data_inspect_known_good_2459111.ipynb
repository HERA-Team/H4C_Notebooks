# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import numpy as np
from pyuvdata import UVCal, UVData
import os
import sys
import glob
import uvtools as uvt
from astropy.time import Time
from astropy.coordinates import EarthLocation, SkyCoord, AltAz, Angle
import pandas
import warnings 
import copy
from hera_notebook_templates import utils
import hera_qm
from hera_mc import cm_hookup
import h5py
import importlib
from scipy import stats
#warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
#get data location
JD = os.environ['JULIANDATE']
data_path = os.environ['DATA_PATH']
ant_metrics_ext = os.environ['ANT_METRICS_EXT']
utc = Time(JD, format='jd').datetime
print(f'JD = {JD}')
print(f'Date = {utc.month}-{utc.day}-{utc.year}')
print(f'data_path = "{data_path}"')
print(f'ant_metrics_ext = "{ant_metrics_ext}"')
# Out:
# JD = 2459111
# Date = 9-18-2020
# data_path = "/mnt/sn1"
# ant_metrics_ext = ".known_good.ant_metrics.hdf5"

# %%
importlib.reload(utils)
# Out:
# <module 'hera_notebook_templates.utils' from '/home/obs/anaconda/envs/RTP/lib/python3.7/site-packages/hera_notebook_templates/utils.py'>

# %%
# Load in data
HHfiles, difffiles, HHautos, diffautos, uvdx, uvdy = utils.load_data(data_path,JD)
ant_metrics_list = [df.replace('.uvh5', ant_metrics_ext) for df in HHfiles]
with h5py.File(ant_metrics_list[100], "r") as infile:
    xants = [int(ant) for ant in infile['Header']['history'][()].decode().split('--apriori_xants')[-1].strip().split(' ')]
    
uvd = UVData()
unread = True
readInd=0
while unread and readInd<len(HHautos):
    try:
        uvd.read(HHautos[readInd])
        unread = False
    except:
        readInd += 1
        continue
use_ants = [int(ant) for ant in uvd.antenna_numbers if ant not in xants]
uvd.read(HHautos[::10], skip_bad_files=True, antenna_nums = use_ants)
lsts = uvd.lst_array
uvdx.select(antenna_nums=use_ants)
uvdy.select(antenna_nums=use_ants)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-4118dc0d7135> in <module>
#       2 HHfiles, difffiles, HHautos, diffautos, uvdx, uvdy = utils.load_data(data_path,JD)
#       3 ant_metrics_list = [df.replace('.uvh5', ant_metrics_ext) for df in HHfiles]
# ----> 4 with h5py.File(ant_metrics_list[100], "r") as infile:
#       5     xants = [int(ant) for ant in infile['Header']['history'][()].decode().split('--apriori_xants')[-1].strip().split(' ')]
#       6
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~/anaconda/envs/RTP/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/mnt/sn1/zen.2459111.64463.sum.known_good.ant_metrics.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# ## LST Coverage

# %% [markdown]
# Shows the LSTs (in hours) and JDs for which data is collected. Green represents data, red means no data.

# %%
utils.plot_lst_coverage(uvd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-851bd911051c> in <module>
# ----> 1 utils.plot_lst_coverage(uvd)
#
# NameError: name 'uvd' is not defined

# %% [markdown]
# ## Autocorrelations for a single file

# %% [markdown]
# This plot shows autocorrelations for one timestamp of each antenna that is active and each polarization. For each node, antennas are ordered by SNAP number, and within that by SNAP input number. The antenna number label color corresponds to the a priori status of that antenna.

# %%
### plot autos
utils.plot_autos(uvdx, uvdy)

# %% [markdown]
# ## Waterfalls of Autocorrelation Amplitudes for each Antenna and Each polarization

# %% [markdown]
# These plots show autocorrelation waterfalls of each antenna that is active and whose status qualifies for this notebook. For each node, antennas are ordered by SNAP number, and within that by SNAP input number. The antenna number label color corresponds to the a priori status of that antenna.

# %%
utils.plot_wfs(uvd, pol = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-67788bcc7d94> in <module>
# ----> 1 utils.plot_wfs(uvd, pol = 0)
#
# NameError: name 'uvd' is not defined

# %%
utils.plot_wfs(uvd, pol = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7db24c66375a> in <module>
# ----> 1 utils.plot_wfs(uvd, pol = 1)
#
# NameError: name 'uvd' is not defined

# %% [markdown]
# ## Correlation Metrics

# %% [markdown]
# The first plot shows the correlation metric (described below) for a set of baseline types, as calculated at several times throughout the night. It is expected that longer baselines (darker color) will exhibit lower values than the short baselines.
#
# The matrices show the phase correlation between antennas. Using the even and odd visibilities, each pixel is calculated as (even/abs(even)) * (conj(odd)/abs(odd)), and then averaged across time and frequency. If the phases are noise-like, this value will average down to zero. If the antennas are well correlated, the phases should not be noise-like, and this value should average to 1. The lines denoting node boundaries are intended to help confirm that inter-node correlations are functioning - if they aren't, this plot will appear block-diagonal.
#
# This metric has shown to be LST locked - when comparing to other nights, be sure to compare for the same LST. It is expected that some LSTs will look much better or worse than others.
#
# Note: Within each node, the order of antennas is determined by snap, and within that by snap input number.

# %%
badAnts = []
badAnts = utils.plotNodeAveragedSummary(uvd,HHfiles,JD,use_ants,mat_pols=['xx','yy','xy','yx'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5f14f0bc7f25> in <module>
#       1 badAnts = []
# ----> 2 badAnts = utils.plotNodeAveragedSummary(uvd,HHfiles,JD,use_ants,mat_pols=['xx','yy','xy','yx'])
#
# NameError: name 'uvd' is not defined

# %% [markdown]
# Visibility amplitude spectra for a set of redundant baselines, labeled by inter vs. intranode baselines. The red and blue should exhibit the same bandpass shape - if the red are consistently different from the blue, this indicates an issue with internode correlations.
#
# Note: antennas that were identified as bad by the correlation matrix have been removed from this plot.

# %%
utils.plotVisibilitySpectra(HHfiles[len(HHfiles)//2+1], JD, use_ants, badAnts=badAnts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-106d61c42e54> in <module>
# ----> 1 utils.plotVisibilitySpectra(HHfiles[len(HHfiles)//2+1], JD, use_ants, badAnts=badAnts)
#
# NameError: name 'use_ants' is not defined

# %% [markdown]
# ## Even and Odd File Checks

# %% [markdown]
# A waterfall showing the ratio between the even and odd visibilities. The purpose of this is to highlight xengine failures, which will cause this value to fall to zero or go to infinity. If things are working properly, this value should be stable at 1. The boundaries between different x-engines are shown by the vertical red lines.

# %%
if len(HHautos) == len(diffautos):
    uvd_diff = UVData()
    uvd_diff.read(diffautos[::10], skip_bad_files=True, antenna_nums=use_ants)
    rat = utils.plotEvenOddWaterfalls(uvd,uvd_diff)
else:
    uvd_diff = UVData()
    use_diffs = [f for f in diffautos if '%s/zen.%s.%s.sum.autos.uvh5' % (data_path,f.split('.')[1],f.split('.')[2]) in HHautos[::10]]
    uvd_diff.read(use_diffs, skip_bad_files=True, antenna_nums = use_ants)
    uvd_sum = uvd.select(times=np.unique(uvd_diff.time_array),inplace=False)
    rat = utils.plotEvenOddWaterfalls(uvd_sum,uvd_diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-805086942b99> in <module>
#       1 if len(HHautos) == len(diffautos):
#       2     uvd_diff = UVData()
# ----> 3     uvd_diff.read(diffautos[::10], skip_bad_files=True, antenna_nums=use_ants)
#       4     rat = utils.plotEvenOddWaterfalls(uvd,uvd_diff)
#       5 else:
#
# NameError: name 'use_ants' is not defined

# %% [markdown]
# ## Antenna Metrics Over a Whole Night

# %%
ant_metrics_list = [df.replace('.uvh5', ant_metrics_ext) for df in HHfiles]
apriori_exants = {}
am_xants_dict = {}
am_dead_ants_dict = {}
am_crossed_ants_dict = {}
for amf in ant_metrics_list:
    try:
        with h5py.File(amf, "r") as infile:
            xants = infile['Metrics']['xants'][:]
            dead_ants = infile['Metrics']['dead_ants'][:]
            crossed_ants = infile['Metrics']['crossed_ants'][:]        
            ex_ants_string = infile['Header']['history'][()].decode()
            ex_ants_string = ex_ants_string.split('--apriori_xants')[1]
            ex_ants_string = ex_ants_string.split('--')[0].strip()
    except:
        print(f'skipping {amf}')
        continue
        
    am_xants_dict[amf] = [(int(ant[0]), ant[1].decode()) for ant in xants]
    am_dead_ants_dict[amf] = [(int(ant[0]), ant[1].decode()) for ant in dead_ants]
    am_crossed_ants_dict[amf] = [(int(ant[0]), ant[1].decode()) for ant in crossed_ants]
    apriori_exants[amf] = [int(ant) for ant in ex_ants_string.split()]


file = HHfiles[0]
uvd_hh = UVData()
uvd_hh.read_uvh5(file)
uvdx = uvd_hh.select(polarizations = -5, inplace = False)
uvdx.ants = np.unique(np.concatenate([uvdx.ant_1_array, uvdx.ant_2_array]))
antstemp = uvdx.get_ants()
ants = []

for ant in antstemp:
    ants.append((ant,'Jee'))
    ants.append((ant, 'Jnn'))
# Out:
# skipping /mnt/sn1/zen.2459111.21216.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21236.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21256.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21276.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21296.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21316.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21336.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21356.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21376.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.21395.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.28680.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.28700.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.28720.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.28740.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.28760.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.29379.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36299.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36319.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36339.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36359.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36378.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36398.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36418.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36438.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.36458.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.37154.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.38111.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.38131.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.38150.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.47445.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.48937.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49334.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49354.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49513.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49533.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49553.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49573.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.49593.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.50649.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.50729.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.50768.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.50808.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63727.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63747.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63767.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63787.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63807.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63827.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63847.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63867.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63886.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63906.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63926.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63946.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63966.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.63986.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64006.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64026.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64045.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64065.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64085.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64105.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64125.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64145.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64165.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64185.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64205.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64224.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64244.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64264.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64284.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64304.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64324.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64344.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64364.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64383.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64403.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64423.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64443.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64463.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64483.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64503.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64523.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64543.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64562.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64582.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64602.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64622.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64642.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64662.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64682.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64702.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64722.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64741.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64761.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64781.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64801.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64821.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64841.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64861.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64881.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64900.sum.known_good.ant_metrics.hdf5
# skipping /mnt/sn1/zen.2459111.64920.sum.known_good.ant_metrics.hdf5

# %%
exants_grid = np.zeros((len(ants),len(HHfiles))) + 4.0
ant_flags_dict = []
flaggedAnts = {}
color_order = ['gold', 'magenta', 'cyan', 'black']

# 0 = apriori, 1 = AM dead, 2 =  AM crossed, 3 = redcal, 4 = no flags 
for f, cal in enumerate(ant_flags_dict):
    for i, ant in enumerate(ants):
        if ant_flags_dict[cal][ant]:
            exants_grid[i, f] = 3.0
for f, amf in enumerate(am_xants_dict):
    for i, ant in enumerate(ants):
        if ant in am_dead_ants_dict[amf]:
            exants_grid[i, f] = 1.0   
        elif ant in am_crossed_ants_dict[amf]:
            exants_grid[i, f] = 2.0
for f, amf in enumerate(apriori_exants):
    for i, ant in enumerate(ants):
        if ant[0] in apriori_exants[amf]:
            exants_grid[i, f] = 0.0
            
for i,ant in enumerate(ants):
    m = int(stats.mode(exants_grid[i,:]).mode)
    if m != 4:
        flaggedAnts[ant[0]] = color_order[m]

from mpl_toolkits.axes_grid1 import make_axes_locatable
cmap = matplotlib.colors.ListedColormap(color_order)
bounds=np.arange(len(color_order)+1)
norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)
            
fig = plt.figure(figsize=(14,len(ants)/4.625))
im = plt.imshow(exants_grid, aspect='auto', cmap=cmap, norm=norm, interpolation='nearest',
                extent=[lsts[0]*12/np.pi, lsts[-1]*12/np.pi, len(ants), 0])
plt.yticks(np.arange(len(ants))+.5, 
           labels = ['{}{}'.format(ant[0], ant[1][-1]) for ant in ants]);
plt.grid(color='w', linestyle='-', linewidth=1.5, axis='y')
plt.xlabel('LST (Hours)')

divider = make_axes_locatable(plt.gca())
cax = divider.new_vertical(size=.4, pad=0.5, pack_start=False)
fig.add_axes(cax)
cbar = fig.colorbar(im, cax=cax, orientation="horizontal")
cbar.set_ticks(.5 + np.arange(len(color_order)))
cbar.set_ticklabels(['Flagged A Priori', 
                     'Flagged by AM as Dead',
                     'Flagged by AM as Crossed',
                     'No Flags', ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-52f3f814fd4d> in <module>
#      32 fig = plt.figure(figsize=(14,len(ants)/4.625))
#      33 im = plt.imshow(exants_grid, aspect='auto', cmap=cmap, norm=norm, interpolation='nearest',
# ---> 34                 extent=[lsts[0]*12/np.pi, lsts[-1]*12/np.pi, len(ants), 0])
#      35 plt.yticks(np.arange(len(ants))+.5,
#      36            labels = ['{}{}'.format(ant[0], ant[1][-1]) for ant in ants]);
#
# NameError: name 'lsts' is not defined

# %% [markdown]
# ## Crossed Antenna Check

# %% [markdown]
# These are differences between different panels of the correlation matrices shown above (see panel titles for specifics). Antennas showing as consistently blue are ones which are correlating stronger in the cross pols than in the auto pols, indicating that the antenna polarizations are likely crossed.

# %%
utils.plotNodeAveragedSummary(uvd,HHfiles,JD,use_ants,mat_pols=['xx','yy','xy','yx'],plotRatios=True,
                                       plotSummary=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-fea20e375c3f> in <module>
# ----> 1 utils.plotNodeAveragedSummary(uvd,HHfiles,JD,use_ants,mat_pols=['xx','yy','xy','yx'],plotRatios=True,
#       2                                        plotSummary=False)
#
# NameError: name 'uvd' is not defined

# %% [markdown]
# ## Antenna Positions

# %% [markdown]
# Antennas outlined in black here have been identified by the correlation matrix as bad antennas. Antennas with a colorful outline correspond to their status as identified by ant_metrics (see above plot). Faded antennas are those not meeting the apriori status requirement for this notebook run. Gold stars are node box locations.

# %%
uvd1 = UVData()
uvd1.read(HHfiles[readInd], skip_bad_files=True)
utils.plot_antenna_positions(uvd1, badAnts=badAnts,flaggedAnts=flaggedAnts,use_ants=use_ants)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9a1c2036b379> in <module>
#       1 uvd1 = UVData()
# ----> 2 uvd1.read(HHfiles[readInd], skip_bad_files=True)
#       3 utils.plot_antenna_positions(uvd1, badAnts=badAnts,flaggedAnts=flaggedAnts,use_ants=use_ants)
#
# NameError: name 'readInd' is not defined

# %% [markdown]
# ## Observer Inspection Plots

# %% [markdown]
# Antennas of status digital_OK or better that are flagged as bad by any of the above metrics are plotted here so observers can inspect their failures in more detail. The line plots are averages over the whole observation. These plots are recommended diagnostics for demoting antennas to lower statuses or reporting issues. If the plots below look OK, check other plots in notebook to hunt why the antenna was flagged. NOTE: The colorbar/power scales in these plots are NOT locked between antennas OR polarizations so that the detail will be visible on all plots. Be sure to check for reasonable power levels, as this may be the reason the antenna was flagged for inspection.

# %%
inspectAnts = utils.plot_inspect_ants(uvd,JD,badAnts=badAnts,flaggedAnts=flaggedAnts,use_ants=use_ants)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-89850fa47a61> in <module>
# ----> 1 inspectAnts = utils.plot_inspect_ants(uvd,JD,badAnts=badAnts,flaggedAnts=flaggedAnts,use_ants=use_ants)
#
# NameError: name 'uvd' is not defined

# %% [markdown]
# ## Mean-Subtracted Waterfalls

# %% [markdown]
# Here the mean value in each frequency bin has been subtracted out. This effectively subtracts out the bandpass shape, making time variations more visible.

# %%
utils.plot_mean_subtracted_wfs(uvd,use_ants,JD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4e651c1b9020> in <module>
# ----> 1 utils.plot_mean_subtracted_wfs(uvd,use_ants,JD)
#
# NameError: name 'uvd' is not defined

# %% [markdown]
# ## Delay spectrum

# %% [markdown]
# Delay spectrum CLEANed using uvtools.dspec.high_pass_fourier_filter with 7th-order Blackman-Harris window function and full frequency band. All delay spectra except for waterfalls are incoherently averaged over ~1h (if the observation is longer than 1h) with odd/even visibilities to remove noise bias.

# %%
# bls = [(ant,ant) for ant in np.sort(uvd.get_ants())]
# _data_sq, data_rs, uvd_ds, uvd_diff = utils.clean_ds(HHfiles, difffiles, bls)

# %% [markdown]
# Diagnosis of delay spectra for three different delay regions:
#
# Top panel: compute delay spectrum over 250-500 ns
#
# Middle panel: compute standard deviation ratio $\sigma_{2500-3000}/\sigma_{3000-3200}$ to see the presence of spike at 2500-3000 ns. ~1 in y-axis (dashed line) means there is no spike, and >1 may indicate the presence of spike in the region
#
# Bottom panel: compute distance between delay spectrum and noise level at large delay (3500-4000 ns). ~0 (dashed line) means the delay spectrum can go down to the noise level

# %%
# utils.plot_ds_diagnosis(uvd_diff, _data_sq)

# %%
# utils.plot_ds_nodes(uvd_diff, _data_sq)

# %%
# utils.plot_wfds(uvd_ds, _data_sq, 'ee')

# %%
# utils.plot_wfds(uvd_ds, _data_sq, 'nn')

# %% [markdown]
# These plots show incoherently averaged (~1h) delay spectra, autocorrelations and clean residuals for each antenna.
#
# Left panel: delay spectra of autocorrelations, averaged noises from diff files (|$<\tilde{\Delta}>_{\rm t}$|, thiner fluctuating lines). The variance of the delay spectrum is also shown ($\sqrt{<|\tilde{\Delta}|^2>_{\rm t}/(2N_{\rm t})}$) which is consistent with the average of diff. Three shaded zones are those explained in the above diagnosis plots.
#
# Top right: autocorrelations w/o and w/ flagging. Autocorrelations are normalized to have median=1. Flagged ones are shifted for clarity.
#
# Bottom right: clean residuals normalized by the autocorrelations. If there are unflagged RFIs, which may affect the delay spectrum, we may see remaining RFI more clearly in the plot.

# %%
# utils.plot_ds(uvd_ds, uvd_diff, _data_sq, data_rs)

# %%
# bls_cr = [(uvd.get_ants()[0],ant) for ant in np.sort(uvd.get_ants())][1:]
# _data_sq_cr, data_rs_cr, uvd_cr, uvd_diff_cr = utils.clean_ds(HHfiles, difffiles, bls_cr)

# %% [markdown]
# Waterfalls for delay spectrum of crosscorrelation with a reference antenna

# %%
# utils.plot_wfds_cr(uvd_cr, _data_sq_cr, 'ee')

# %%
# utils.plot_wfds_cr(uvd_cr, _data_sq_cr, 'nn')
